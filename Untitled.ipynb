# %%
import os
import torch

cpu_count = os.cpu_count()
print(f"服务器 CPU 核心数: {cpu_count}")

# 推荐策略
suggested_workers = min(16, cpu_count - 2)  # 留 2 个核给系统和主进程
print(f"🔥 建议设置 --num_workers {suggested_workers}")
# Out:
# 服务器 CPU 核心数: 208
# 🔥 建议设置 --num_workers 16
